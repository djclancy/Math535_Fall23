# %% [markdown]
# # Spectral Graph theory motivation: Community Detection

# %% [markdown]
# Many types of data come in the form of **networks**.
#
# Often times there is some *hidden* or *latent* structure in the data that we wish to analyze.

# %%
import networkx as nx
import numpy as np
import cdlib

# %%
n = 300
p = 5*np.log(n)/n
q = 1*np.log(n)/n
G = nx.planted_partition_graph(n,2,p,q)

# %%
pos = nx.spring_layout(G)
nx.draw(G,pos)

# %%
leiden_coms = cdlib.algorithms.leiden(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 leiden_coms = cdlib.algorithms.leiden(g)
#
# AttributeError: module 'cdlib' has no attribute 'algorithms'

# %%
cdlib.BiNodeClustering.
